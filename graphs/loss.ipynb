# %%
import matplotlib.pyplot as plt

x = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
y = [3070, 497, 114, 85.3, 69.8, 30.5, 21.8, 23.5, 18.3, 17, 13.7]

plt.plot(x, y)
plt.xlabel('Epoch')
plt.ylabel('Epoch Loss')
plt.show()
