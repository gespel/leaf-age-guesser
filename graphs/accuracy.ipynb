# %%
# Gegebene Daten erneut definieren
data = [(136.81497192382812, 104.0), (7.374781608581543, 10.0), (13.086541175842285, 11.0), (84.46126556396484, 111.0), (10.454367637634277, 12.0), (11.040096282958984, 12.0), (13.734821319580078, 13.0), (9.394997596740723, 14.0), (131.30728149414062, 140.0), (5.334049224853516, 15.0), (15.823606491088867, 16.0), (125.85501861572266, 170.0), (23.676862716674805, 17.0), (23.43057632446289, 18.0), (21.43846893310547, 18.0), (23.066600799560547, 19.0), (29.106346130371094, 20.0), (25.21344757080078, 21.0), (19.8702392578125, 23.0), (180.4061279296875, 240.0), (12.801708221435547, 27.0), (38.35926818847656, 28.0), (74.57019805908203, 28.0), (7.082045078277588, 2.0), (5.160201072692871, 2.0), (25.65097427368164, 31.0), (71.66165924072266, 32.0), (62.509178161621094, 33.0), (21.758073806762695, 34.0), (18.165393829345703, 35.0), (20.396259307861328, 37.0), (43.70335006713867, 39.0), (52.87302780151367, 41.0), (34.7665901184082, 42.0), (47.28217697143555, 45.0), (44.82379913330078, 49.0), (6.311980247497559, 4.0), (44.6549186706543, 53.0), (49.54848861694336, 55.0), (10.217085838317871, 5.0), (14.788949012756348, 5.0), (7.126336574554443, 5.0), (64.25140380859375, 79.0), (14.753653526306152, 7.0), (16.105314254760742, 9.0), (4.268445014953613, 9.0)]

predicted, actual = zip(*data)

plt.figure(figsize=(8, 6))
plt.scatter(actual, predicted, alpha=0.6, label="Datapoints", marker='x')
plt.plot([min(actual), max(actual)], [min(actual), max(actual)], linestyle="--", color="red", label="Ideal Fit")

plt.xlabel("Actual Leaf Size Values")
plt.ylabel("Predicted Leaf Size Values")
plt.title("Predicted vs Actual Leaf Size")

plt.legend()

plt.show()
